# %%
# Dependencies and Setup

import pandas as pd
import numpy as np

# %%
# Importing data files

census_df = pd.read_csv("Resources/census_us_county_output.csv")
education_df = pd.read_csv("Resources/ers_usda_education.csv")

# %%
census_df
# Out:
#       County                        Name  Population  Median Age  \
# 0         51    Fayette County, Illinois     21565.0        41.9
# 1        107      Logan County, Illinois     29003.0        40.1
# 2        165     Saline County, Illinois     23994.0        42.2
# 3         97       Lake County, Illinois    701473.0        38.4
# 4        127     Massac County, Illinois     14219.0        43.5
# ...      ...                         ...         ...         ...
# 3215      33  Crockett County, Tennessee     14399.0        40.7
# 3216      95      Lake County, Tennessee      7401.0        41.5
# 3217      93      Knox County, Tennessee    461104.0        37.4
# 3218       5   Benton County, Washington    197518.0        35.8
# 3219      11    Clark County, Washington    473252.0        38.4
#
#       Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0              46650.0            23194.0         3421.0     15.863668
# ...

# %%
# Reseting index
census_df = census_df.reset_index(drop=True)

# %%
# Remove column name 'A'
census_df = census_df.drop(['County'], axis = 1)
census_df
# Out:
#                             Name  Population  Median Age  Household Income  \
# 0       Fayette County, Illinois     21565.0        41.9           46650.0
# 1         Logan County, Illinois     29003.0        40.1           57308.0
# 2        Saline County, Illinois     23994.0        42.2           44090.0
# 3          Lake County, Illinois    701473.0        38.4           89427.0
# 4        Massac County, Illinois     14219.0        43.5           47481.0
# ...                          ...         ...         ...               ...
# 3215  Crockett County, Tennessee     14399.0        40.7           44717.0
# 3216      Lake County, Tennessee      7401.0        41.5           35191.0
# 3217      Knox County, Tennessee    461104.0        37.4           57470.0
# 3218   Benton County, Washington    197518.0        35.8           69023.0
# 3219    Clark County, Washington    473252.0        38.4           75253.0
#
# ...

# %%
census_df[['County','State']] = census_df.Name.str.split(",",expand=True,)
census_df
# Out:
#                             Name  Population  Median Age  Household Income  \
# 0       Fayette County, Illinois     21565.0        41.9           46650.0
# 1         Logan County, Illinois     29003.0        40.1           57308.0
# 2        Saline County, Illinois     23994.0        42.2           44090.0
# 3          Lake County, Illinois    701473.0        38.4           89427.0
# 4        Massac County, Illinois     14219.0        43.5           47481.0
# ...                          ...         ...         ...               ...
# 3215  Crockett County, Tennessee     14399.0        40.7           44717.0
# 3216      Lake County, Tennessee      7401.0        41.5           35191.0
# 3217      Knox County, Tennessee    461104.0        37.4           57470.0
# 3218   Benton County, Washington    197518.0        35.8           69023.0
# 3219    Clark County, Washington    473252.0        38.4           75253.0
#
# ...

# %%
census_df = census_df.drop_duplicates()
census_df
# Out:
#                             Name  Population  Median Age  Household Income  \
# 0       Fayette County, Illinois     21565.0        41.9           46650.0
# 1         Logan County, Illinois     29003.0        40.1           57308.0
# 2        Saline County, Illinois     23994.0        42.2           44090.0
# 3          Lake County, Illinois    701473.0        38.4           89427.0
# 4        Massac County, Illinois     14219.0        43.5           47481.0
# ...                          ...         ...         ...               ...
# 3215  Crockett County, Tennessee     14399.0        40.7           44717.0
# 3216      Lake County, Tennessee      7401.0        41.5           35191.0
# 3217      Knox County, Tennessee    461104.0        37.4           57470.0
# 3218   Benton County, Washington    197518.0        35.8           69023.0
# 3219    Clark County, Washington    473252.0        38.4           75253.0
#
# ...

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_df.to_csv("Resources/cleaned_census_data.csv", encoding="utf-8", index=False)

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3220 entries, 0 to 3219
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               3220 non-null   object
#  1   Population         3220 non-null   float64
#  2   Median Age         3220 non-null   float64
#  3   Household Income   3220 non-null   float64
#  4   Per Capita Income  3220 non-null   float64
#  5   Poverty Count      3220 non-null   float64
#  6   Poverty Rate       3220 non-null   float64
#  7   Unemployment Rate  3220 non-null   float64
#  8   County             3220 non-null   object
#  9   State              3220 non-null   object
# dtypes: float64(7), object(3)
# memory usage: 276.7+ KB

# %%
education_df
# Out:
#       FIPS Code State            Area name  2003 Rural-urban Continuum Code  \
# 0             0    US        United States                              NaN
# 1          1000    AL              Alabama                              NaN
# 2          1001    AL       Autauga County                              2.0
# 3          1003    AL       Baldwin County                              4.0
# 4          1005    AL       Barbour County                              6.0
# ...         ...   ...                  ...                              ...
# 3278      72145    PR  Vega Baja Municipio                              1.0
# 3279      72147    PR    Vieques Municipio                              7.0
# 3280      72149    PR   Villalba Municipio                              2.0
# 3281      72151    PR    Yabucoa Municipio                              1.0
# 3282      72153    PR      Yauco Municipio                              3.0
#
# ...

# %%
# Reseting index
education_df = education_df.reset_index(drop=True)

# %%
education_df = education_df.iloc[2:]
education_df
# Out:
#       FIPS Code State            Area name  2003 Rural-urban Continuum Code  \
# 2          1001    AL       Autauga County                              2.0
# 3          1003    AL       Baldwin County                              4.0
# 4          1005    AL       Barbour County                              6.0
# 5          1007    AL          Bibb County                              1.0
# 6          1009    AL        Blount County                              1.0
# ...         ...   ...                  ...                              ...
# 3278      72145    PR  Vega Baja Municipio                              1.0
# 3279      72147    PR    Vieques Municipio                              7.0
# 3280      72149    PR   Villalba Municipio                              2.0
# 3281      72151    PR    Yabucoa Municipio                              1.0
# 3282      72153    PR      Yauco Municipio                              3.0
#
# ...

# %%
# to see null rows
# education_df.info()

# %%
# Reset index
education_df = education_df.reset_index(drop=True)

# %%
education_df
# Out:
#       FIPS Code State            Area name  2003 Rural-urban Continuum Code  \
# 0          1001    AL       Autauga County                              2.0
# 1          1003    AL       Baldwin County                              4.0
# 2          1005    AL       Barbour County                              6.0
# 3          1007    AL          Bibb County                              1.0
# 4          1009    AL        Blount County                              1.0
# ...         ...   ...                  ...                              ...
# 3276      72145    PR  Vega Baja Municipio                              1.0
# 3277      72147    PR    Vieques Municipio                              7.0
# 3278      72149    PR   Villalba Municipio                              2.0
# 3279      72151    PR    Yabucoa Municipio                              1.0
# 3280      72153    PR      Yauco Municipio                              3.0
#
# ...

# %%
# Rename column
# df=df.rename(columns = {'two':'new_name'})


education_df = education_df.rename(columns = {'Area name':'County'})
education_df
# Out:
#       FIPS Code State               County  2003 Rural-urban Continuum Code  \
# 0          1001    AL       Autauga County                              2.0
# 1          1003    AL       Baldwin County                              4.0
# 2          1005    AL       Barbour County                              6.0
# 3          1007    AL          Bibb County                              1.0
# 4          1009    AL        Blount County                              1.0
# ...         ...   ...                  ...                              ...
# 3276      72145    PR  Vega Baja Municipio                              1.0
# 3277      72147    PR    Vieques Municipio                              7.0
# 3278      72149    PR   Villalba Municipio                              2.0
# 3279      72151    PR    Yabucoa Municipio                              1.0
# 3280      72153    PR      Yauco Municipio                              3.0
#
# ...

# %%
# Remove all columns between column index 3 to 31

education_df = education_df.drop(education_df.iloc[:, 3:31], axis = 1)
education_df
# Out:
#       FIPS Code State               County  \
# 0          1001    AL       Autauga County
# 1          1003    AL       Baldwin County
# 2          1005    AL       Barbour County
# 3          1007    AL          Bibb County
# 4          1009    AL        Blount County
# ...         ...   ...                  ...
# 3276      72145    PR  Vega Baja Municipio
# 3277      72147    PR    Vieques Municipio
# 3278      72149    PR   Villalba Municipio
# 3279      72151    PR    Yabucoa Municipio
# 3280      72153    PR      Yauco Municipio
#
#      Less than a high school diploma, 2000 High school diploma only, 2000  \
# 0                                    5,872                          9,332
# 1                                   17,258                         28,428
# 2                                    6,679                          6,124
# 3                                    4,984                          4,838
# ...

# %%
# education_df.rename(columns = {'test':'TEST', 'odi':'ODI',
#                               't20':'T20'}, inplace = True)

# column_names = list(df.columns)
# column_names[4:8] = ['five', 'six', 'seven', 'eight']
# df.columns = column_names

column_names = list(education_df.columns)
column_names[3:19] = ['Below_HS_Diploma_2000', 'HS_Diploma_2000', 'College_or_Associate_2000', 'Bachelor_or_Higher_2000',
                    'Percent_Below_HS_Diploma_2000', 'Percent_HS_Diploma_2000', 'Percent_College_or_Associate_2000', 'Percent_Bachelor_or_Higher_2000',
                    'Below_HS_Diploma_2019', 'HS_Diploma_2019', 'College_or_Associate_2019', 'Bachelor_or_Higher_2019',
                    'Percent_Below_HS_Diploma_2019', 'Percent_HS_Diploma_2019', 'Percent_College_or_Associate_2019', 'Percent_Bachelor_or_Higher_2019',]
education_df.columns = column_names

# %%
education_df
# Out:
#       FIPS Code State               County Below_HS_Diploma_2000  \
# 0          1001    AL       Autauga County                 5,872
# 1          1003    AL       Baldwin County                17,258
# 2          1005    AL       Barbour County                 6,679
# 3          1007    AL          Bibb County                 4,984
# 4          1009    AL        Blount County                 9,960
# ...         ...   ...                  ...                   ...
# 3276      72145    PR  Vega Baja Municipio                15,973
# 3277      72147    PR    Vieques Municipio                 2,767
# 3278      72149    PR   Villalba Municipio                 6,501
# 3279      72151    PR    Yabucoa Municipio                10,478
# 3280      72153    PR      Yauco Municipio                12,068
#
#      HS_Diploma_2000 College_or_Associate_2000 Bachelor_or_Higher_2000  \
# 0              9,332                     7,413                   4,972
# ...

# %%
education_df = education_df.drop_duplicates()
education_df
# Out:
#       FIPS Code State               County Below_HS_Diploma_2000  \
# 0          1001    AL       Autauga County                 5,872
# 1          1003    AL       Baldwin County                17,258
# 2          1005    AL       Barbour County                 6,679
# 3          1007    AL          Bibb County                 4,984
# 4          1009    AL        Blount County                 9,960
# ...         ...   ...                  ...                   ...
# 3276      72145    PR  Vega Baja Municipio                15,973
# 3277      72147    PR    Vieques Municipio                 2,767
# 3278      72149    PR   Villalba Municipio                 6,501
# 3279      72151    PR    Yabucoa Municipio                10,478
# 3280      72153    PR      Yauco Municipio                12,068
#
#      HS_Diploma_2000 College_or_Associate_2000 Bachelor_or_Higher_2000  \
# 0              9,332                     7,413                   4,972
# ...

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
education_df.to_csv("Resources/cleaned_education_data.csv", encoding="utf-8", index=False)

# %%
education_df.columns
# Out:
# Index(['FIPS Code', 'State', 'County', 'Below_HS_Diploma_2000',
#        'HS_Diploma_2000', 'College_or_Associate_2000',
#        'Bachelor_or_Higher_2000', 'Percent_Below_HS_Diploma_2000',
#        'Percent_HS_Diploma_2000', 'Percent_College_or_Associate_2000',
#        'Percent_Bachelor_or_Higher_2000', 'Below_HS_Diploma_2019',
#        'HS_Diploma_2019', 'College_or_Associate_2019',
#        'Bachelor_or_Higher_2019', 'Percent_Below_HS_Diploma_2019',
#        'Percent_HS_Diploma_2019', 'Percent_College_or_Associate_2019',
#        'Percent_Bachelor_or_Higher_2019'],
#       dtype='object')

# %%
# fips_code_df = education_df.filter(['FIPS Code','State','County'], axis=1)
# fips_code_df.reset_index()

fips_code_df = education_df[['FIPS Code', 'State', 'County']].copy()
fips_code_df
# Out:
#       FIPS Code State               County
# 0          1001    AL       Autauga County
# 1          1003    AL       Baldwin County
# 2          1005    AL       Barbour County
# 3          1007    AL          Bibb County
# 4          1009    AL        Blount County
# ...         ...   ...                  ...
# 3276      72145    PR  Vega Baja Municipio
# 3277      72147    PR    Vieques Municipio
# 3278      72149    PR   Villalba Municipio
# 3279      72151    PR    Yabucoa Municipio
# 3280      72153    PR      Yauco Municipio
#
# [3281 rows x 3 columns]

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
fips_code_df.to_csv("Resources/cleaned_fips_code_data.csv", encoding="utf-8", index=False)

# %%
merge_df = pd.merge(census_df, education_df, on=['State', 'County'], how='inner')

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
merge_df.to_csv("Resources/cleaned_merge_data.csv", encoding="utf-8", index=False)
